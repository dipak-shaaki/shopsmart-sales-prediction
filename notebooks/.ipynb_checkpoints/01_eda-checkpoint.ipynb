# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
sys.path.append("..")      
from src.load_data import load_raw_data

# %% [markdown]
# ### Load data

# %%
df = load_raw_data("data\raw\data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = load_raw_data("data\raw\data.csv")
#
# File D:\shopsmart-sales-prediction\src\load_data.py:7, in load_raw_data(filepath)
#       4 def load_raw_data(filepath):
#       6     if not os.path.exists(filepath):
# ----> 7         raise FileNotFoundError(
#       8             f"Data file not found at: {filepath}\n"
#       9             f"Make sure you placed the CSV in data/raw/"
#      10         )
#      12     df = pd.read_csv(filepath)
#      15     print(f" Loaded data: {df.shape[0]:,} rows, {df.shape[1]} columns")
#
# aw\data.csv
# Make sure you placed the CSV in data/raw/
